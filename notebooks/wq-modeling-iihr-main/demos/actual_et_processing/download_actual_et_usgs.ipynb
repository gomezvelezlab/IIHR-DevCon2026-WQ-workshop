# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

import os, sys
sys.path.append('../../src/actual_et_usgs')

from process_actual_et_usgs import *

URL = "https://edcintl.cr.usgs.gov/downloads/sciweb1/shared/uswem/web/conus/eta/modis_eta/daily/downloads/"
SAVE_DIR = "/home/jgomezvelez/LSS/lss_jgomezvelez/jgomezvelez_data/actual_et_usgs"

# %% [markdown]
# # Download the files

# %%
zip_files_names = list_zip_files(URL)
zip_files_names = [ff for ff in zip_files_names if ff.startswith("20")]
zip_files_names
# Out:
# ['2000.zip',
#  '2001.zip',
#  '2002.zip',
#  '2003.zip',
#  '2004.zip',
#  '2005.zip',
#  '2006.zip',
#  '2007.zip',
#  '2008.zip',
#  '2009.zip',
#  '2010.zip',
#  '2011.zip',
#  '2012.zip',
#  '2013.zip',
#  '2014.zip',
#  '2015.zip',
#  '2016.zip',
#  '2017.zip',
#  '2018.zip',
#  '2019.zip',
#  '2020.zip',
#  '2021.zip',
#  '2022.zip',
#  '2023.zip',
#  '2024.zip']

# %% [markdown]
# # Get file names

# %%
download_usgs_data(file_names = zip_files_names[:1], base_url = URL, target_dir = SAVE_DIR, force_download = False)
